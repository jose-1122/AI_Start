# %%
#https://github.com/mwaskom/seaborn-data

import seaborn as sns

car_crashes = sns.load_dataset("car_crashes")
print(car_crashes, "\n")
print("type(car_crashes) : ", type(car_crashes), "\n")
print("car_crashes.shape : ", car_crashes.shape)
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
car_crashes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   total           51 non-null     float64
#  1   speeding        51 non-null     float64
#  2   alcohol         51 non-null     float64
#  3   not_distracted  51 non-null     float64
#  4   no_previous     51 non-null     float64
#  5   ins_premium     51 non-null     float64
#  6   ins_losses      51 non-null     float64
#  7   abbrev          51 non-null     object
# dtypes: float64(7), object(1)
# memory usage: 3.3+ KB

# %%
# 앞의 데이터만 살펴보기
car_crashes.head() # 괄호 안에 숫자만큼 출력. Default == 5
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %%
# 뒤의 데이터만 살펴보기
car_crashes.tail() # 괄호 안에 숫자만큼 출력. Default == 5
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 46   12.7     2.413    3.429          11.049       11.176       768.95
# 47   10.6     4.452    3.498           8.692        9.116       890.03
# 48   23.8     8.092    6.664          23.086       20.706       992.61
# 49   13.8     4.968    4.554           5.382       11.592       670.31
# 50   17.4     7.308    5.568          14.094       15.660       791.14
#
#     ins_losses abbrev
# 46      153.72     VA
# 47      111.62     WA
# 48      152.56     WV
# 49      106.62     WI
# 50      122.04     WY

# %%
car_crashes.columns
# Out:
# Index(['total', 'speeding', 'alcohol', 'not_distracted', 'no_previous',
#        'ins_premium', 'ins_losses', 'abbrev'],
#       dtype='object')

# %%
car_crashes.describe()
# Out:
#            total   speeding    alcohol  not_distracted  no_previous  \
# count  51.000000  51.000000  51.000000       51.000000    51.000000
# mean   15.790196   4.998196   4.886784       13.573176    14.004882
# std     4.122002   2.017747   1.729133        4.508977     3.764672
# min     5.900000   1.792000   1.593000        1.760000     5.900000
# 25%    12.750000   3.766500   3.894000       10.478000    11.348000
# 50%    15.600000   4.608000   4.554000       13.857000    13.775000
# 75%    18.500000   6.439000   5.604000       16.140000    16.755000
# max    23.900000   9.450000  10.038000       23.661000    21.280000
#
#        ins_premium  ins_losses
# count    51.000000   51.000000
# mean    886.957647  134.493137
# std     178.296285   24.835922
# min     641.960000   82.750000
# 25%     768.430000  114.645000
# 50%     858.970000  136.050000
# 75%    1007.945000  151.870000
# max    1301.520000  194.780000

# %%
import matplotlib.pyplot as plt
plt.hist(car_crashes.speeding) #plt.hist(dataset, range = (최소값, 최대값), bins = 구간 개수), bin' default == 10
# Out:
# (array([ 6.,  3., 11.,  7.,  7.,  4.,  3.,  5.,  2.,  3.]),
#  array([1.792 , 2.5578, 3.3236, 4.0894, 4.8552, 5.621 , 6.3868, 7.1526,
#         7.9184, 8.6842, 9.45  ]),
#  <a list of 10 Patch objects>)

# %%
plt.figure(figsize=(15,20))

plt.subplot(6, 1, 1) # (그래프 전체 크기를) 가로 6등분 * 세로 1등분으로 subplot 을 잡은 것 중 1번째.
plt.hist(car_crashes.total)

plt.subplot(6, 2, 3) # (그래프 전체 크기를) 가로 6등분 * 세로 2등분으로 subplot 을 잡은 것 중 3번째.
plt.hist(car_crashes.speeding)

plt.subplot(6, 2, 4) # (그래프 전체 크기를) 가로 6등분 * 세로 2등분으로 subplot 을 잡은 것 중 4번째.
plt.hist(car_crashes.alcohol)

plt.subplot(6, 1, 3) # (그래프 전체 크기를) 가로 6등분 * 세로 1등분으로 subplot 을 잡은 것 중 3번째.
plt.hist(car_crashes.not_distracted)

plt.subplot(6, 1, 4) # (그래프 전체 크기를) 가로 6등분 * 세로 1등분으로 subplot 을 잡은 것 중 4번째.
plt.hist(car_crashes.no_previous)

plt.subplot(6, 1, 5) # (그래프 전체 크기를) 가로 6등분 * 세로 1등분으로 subplot 을 잡은 것 중 5번째.
plt.hist(car_crashes.ins_premium)

plt.subplot(6, 1, 6) # (그래프 전체 크기를) 가로 6등분 * 세로 1등분으로 subplot 을 잡은 것 중 6번째.
plt.hist(car_crashes.ins_losses)
# Out:
# (array([ 2.,  3., 10.,  4.,  9.,  8., 10.,  2.,  1.,  2.]),
#  array([ 82.75 ,  93.953, 105.156, 116.359, 127.562, 138.765, 149.968,
#         161.171, 172.374, 183.577, 194.78 ]),
#  <a list of 10 Patch objects>)
